# %%
from AskInput import*
from FileAtt import*
from Combiner import*
from Format_func import*

# %% [markdown]
# List the Files inside The Directory
# Change the folder path of

# %%
import os                                                                                                             
import pandas as pd  
import time
from datetime import datetime

machine_fpath_state = False
while not machine_fpath_state:
    machine_fpath = input("Please input path directory")
    if os.path.exists(machine_fpath) == False:
        print("Please input a correct file path")
    else:
        machine_fpath_state = True
        
vhms = list_files(machine_fpath)
vhms_pd = pd.DataFrame(vhms)
vhms_pd.rename(columns = {0:"File Path"}, inplace = True)
vhms_pd
# Out:
# Please input path directoryC:\Users\User\Desktop\New folder (2)
#                                               File Path
# 0     C:\Users\User\Desktop\New folder (2)\30259\201...
# 1     C:\Users\User\Desktop\New folder (2)\30259\201...
# 2     C:\Users\User\Desktop\New folder (2)\30259\201...
# 3     C:\Users\User\Desktop\New folder (2)\30259\201...
# 4     C:\Users\User\Desktop\New folder (2)\30259\201...
# ...                                                 ...
# 9157  C:\Users\User\Desktop\New folder (2)\34188\202...
# 9158  C:\Users\User\Desktop\New folder (2)\34188\202...
# 9159  C:\Users\User\Desktop\New folder (2)\34188\202...
# 9160  C:\Users\User\Desktop\New folder (2)\34188\202...
# 9161  C:\Users\User\Desktop\New folder (2)\34188\202...
#
# [9162 rows x 1 columns]

# %% [markdown]
# C:\Users\User\Desktop\New folder (2)This will find a certain name in the string
# In this case files with "pld" is the one that we are trying to find
# Change the string on the target_file variable

# %%
command = input("Choose the number of which file to compile \n 1. Pldcycn \n 2.Fault \n 3.LR File \n")
match command:
    case "1":
        target_file = "pld"
    case 2:
        target_file = "fault"
    case "3":
        target_file = "LR"

vhms_pd = vhms_pd[vhms_pd["File Path"].str.contains(target_file)]
v_list = vhms_pd.values.tolist()
v_list
# Out:
# Choose the number of which file to compile
#  1. Pldcycn
#  2.Fault
#  3.LR File
# 1
# []

# %% [markdown]
# The code below will determine the time creation and the folder time on the vhms data (medyo daya na method).
# Still looking for the best way

# %%
fileatt = file_att_implementor(v_list)
fileatt
#file_org = pd.DataFrame(list(zip(fileatt)))
fileatt["Helper Column"] = round((fileatt["Folder Name Time"].astype(int)/1)-0.499999)
fileatt
# Out:
#                                              File Path        Modified Time  \
# 233  [C:\Users\User\Desktop\New folder (2)\34188\20...  2023-01-20 00:05:40
# 212  [C:\Users\User\Desktop\New folder (2)\33854\20...  2023-01-20 00:01:00
# 194  [C:\Users\User\Desktop\New folder (2)\33849\20...  2023-01-20 00:20:00
# 230  [C:\Users\User\Desktop\New folder (2)\33857\20...  2023-01-20 00:13:06
# 193  [C:\Users\User\Desktop\New folder (2)\33849\20...  2023-01-14 00:05:44
# ..                                                 ...                  ...
# 4    [C:\Users\User\Desktop\New folder (2)\30259\20...  2019-12-13 14:05:24
# 3    [C:\Users\User\Desktop\New folder (2)\30259\20...  2019-12-11 14:18:52
# 2    [C:\Users\User\Desktop\New folder (2)\30259\20...  2019-12-09 14:40:22
# 1    [C:\Users\User\Desktop\New folder (2)\30259\20...  2019-12-06 14:18:50
# 0    [C:\Users\User\Desktop\New folder (2)\30259\20...  2019-12-05 14:23:58
#
#     Folder Name Time Machine Serial No.  Helper Column
# 233         20230119              34188     20230119.0
# 212         20230119              33854     20230119.0
# 194         20230119              33849     20230119.0
# 230         20230119              33857     20230119.0
# 193         20230113              33849     20230113.0
# ..               ...                ...            ...
# 4           20191213              30259     20191213.0
# 3           20191211              30259     20191211.0
# 2           20191209              30259     20191209.0
# 1           20191206              30259     20191206.0
# 0           20191205              30259     20191205.0
#
# [234 rows x 5 columns]

# %%
fileatt = fileatt.drop_duplicates(subset = ["Machine Serial No.", "Helper Column"], keep =False)

# %%
p1 = AskInput(4, "Input a starting date 'YYYY' \n", "Please enter a correct year \n", "Wrong input, Follow format 'yyyy'")
p2 = p1.input_num()
p3 = AskInput(2, "Input the month 'MM' \n", "Please enter a correct month format 'MM' \n", "Wrong input, Follow format 'MM'")
p4 = p3.input_num()
p5 = p2 + '-' + p4
filtered_files = fileatt.loc[(fileatt["Modified Time"] >= p5)]
ff_list = filtered_files['File Path'].to_list()
ff_list
# Out:
# Input a starting date 'YYYY'
# 2022
# Input the month 'MM'
# 03
# [['C:\\Users\\User\\Desktop\\New folder (2)\\34188\\20230119\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20230119\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20230119\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20230119\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20230113\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20230103\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20230103\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20230103\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\34187\\20230103\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20221226\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\34188\\20221226\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20221226\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20221225\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20221214\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20221210\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20221210\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20221206\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20221206\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20221206\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20221125\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20221122\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20221122\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20221122\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20221115\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20221115\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20221115\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20221103\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20221103\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20221026\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20221026\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20221026\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20220929\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220929\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20220926\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20220914\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20220914\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220914\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20220914\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220908\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20220906\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20220906\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20220906\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220901\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220827\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220825\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20220819\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20220819\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20220819\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220817\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20220810\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20220810\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20220802\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20220802\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220729\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20220718\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20220709\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20220708\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20220628\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20220628\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20220628\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220627\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20220614\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33849\\20220608\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33854\\20220608\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\33857\\20220606\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220601\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220526\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220519\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220516\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220514\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220401\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220323\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220321\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220318\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220316\\CHK0001\\pldcycn23.CSV'],
#  ['C:\\Users\\User\\Desktop\\New folder (2)\\30296\\20220309\\CHK0001\\pldcycn23.CSV']]

# %%
combined = pld_combiner(ff_list)

# %%
#combined3.drop_duplicates(keep = False)
#combined3[combined3.duplicated()]
#combined2[combined2.duplicated(subset = ["Calendar"], keep = False)]
combined
# Out:
#    Axis Item            Calendar Payload Empty Drv.Time Empty Drv.Dist.  \
# 2        NaN  1670899131|28800|0     451            134              40
# 3        NaN  1670901185|28800|0     627            115              33
# 4        NaN  1670909975|28800|0     615            285              70
# 5        NaN  1670914852|28800|0     694            244              72
# 6        NaN  1670917547|28800|0     637            123              37
# ..       ...                 ...     ...            ...             ...
# 2        NaN  1572242601|28800|0     904             10               1
# 2        NaN  1572241184|28800|0     790            114              32
# 2        NaN  1572208373|28800|0     946            157              41
# 3        NaN  1572238703|28800|0     869            354              93
# 2        NaN  1572201235|28800|0     852            135              34
#
#    Empty Stop Time LoadingStopTime Loaded Drv.Time Loaded Drv.Dist.  \
# 2              246              11             204               42
# 3               52              14             153               34
# 4              658              19             153               34
# 5              221              14             173               39
# 6               90              21             198               39
# ..             ...             ...             ...              ...
# 2                3              29             188               49
# 2              122              45             119               31
# 2              111              21             196               36
# 3              134              26             128               31
# 2               45              19             229               37
#
#    Loaded Stop Time  Over Load  Over Speed Limit Speed  Truck ID  Open ID  \
# 2                42        0.0         0.0          40       0.0      0.0
# 3                 2        0.0         0.0          40       0.0      0.0
# 4                 8        0.0         0.0          40       0.0      0.0
# 5                10        0.0         0.0          40       0.0      0.0
# 6                13        0.0         0.0          40       0.0      0.0
# ..              ...        ...         ...         ...       ...      ...
# 2                 1        0.0         0.0          99       0.0      0.0
# 2                 8        0.0         0.0          99       0.0      0.0
# 2                 0        0.0         0.0          99       0.0      0.0
# 3                 4        0.0         0.0          99       0.0      0.0
# 2                40        0.0         0.0          99       0.0      0.0
#
#    Angle Min Angle Ave Angle Max  Machine Serial
# 2       -106        51       133           34188
# 3        -82        68       140           34188
# 4        -88        61       141           34188
# 5        -97        74       142           34188
# 6        -86        82       149           34188
# ..       ...       ...       ...             ...
# 2        -86        45       136           30296
# 2       -132        17       133           30296
# 2        -54        86       150           30296
# 3       -119        14       133           30296
# 2        -80        78       150           30296
#
# [15755 rows x 19 columns]

# %% [markdown]
# Convert dataframe to float and divide columns that is needing division

# %%
dcombined = pld_formatter(combined)

# %%
dcombined
# Out:
#         Calendar  Payload  Empty Drv.Time  Empty Drv.Dist.  Empty Stop Time  \
# 2   44908.443646     45.1            13.4              4.0             24.6
# 3   44908.467419     62.7            11.5              3.3              5.2
# 4   44908.569155     61.5            28.5              7.0             65.8
# 5   44908.625602     69.4            24.4              7.2             22.1
# 6   44908.656794     63.7            12.3              3.7              9.0
# ..           ...      ...             ...              ...              ...
# 2   43766.585660     90.4             1.0              0.1              0.3
# 2   43766.569259     79.0            11.4              3.2             12.2
# 2   43766.189502     94.6            15.7              4.1             11.1
# 3   43766.540544     86.9            35.4              9.3             13.4
# 2   43766.106887     85.2            13.5              3.4              4.5
#
#     LoadingStopTime  Loaded Drv.Time  Loaded Drv.Dist.  Loaded Stop Time  \
# 2               1.1             20.4               4.2               4.2
# 3               1.4             15.3               3.4               0.2
# 4               1.9             15.3               3.4               0.8
# 5               1.4             17.3               3.9               1.0
# 6               2.1             19.8               3.9               1.3
# ..              ...              ...               ...               ...
# 2               2.9             18.8               4.9               0.1
# 2               4.5             11.9               3.1               0.8
# 2               2.1             19.6               3.6               0.0
# 3               2.6             12.8               3.1               0.4
# 2               1.9             22.9               3.7               4.0
#
#     Over Load  Over Speed  Limit Speed  Truck ID  Open ID  Angle Min  \
# 2         0.0         0.0         40.0       0.0      0.0     -106.0
# 3         0.0         0.0         40.0       0.0      0.0      -82.0
# 4         0.0         0.0         40.0       0.0      0.0      -88.0
# 5         0.0         0.0         40.0       0.0      0.0      -97.0
# 6         0.0         0.0         40.0       0.0      0.0      -86.0
# ..        ...         ...          ...       ...      ...        ...
# 2         0.0         0.0         99.0       0.0      0.0      -86.0
# 2         0.0         0.0         99.0       0.0      0.0     -132.0
# 2         0.0         0.0         99.0       0.0      0.0      -54.0
# 3         0.0         0.0         99.0       0.0      0.0     -119.0
# 2         0.0         0.0         99.0       0.0      0.0      -80.0
#
#     Angle Ave  Angle Max  Machine Serial
# 2        51.0      133.0           34188
# 3        68.0      140.0           34188
# 4        61.0      141.0           34188
# 5        74.0      142.0           34188
# 6        82.0      149.0           34188
# ..        ...        ...             ...
# 2        45.0      136.0           30296
# 2        17.0      133.0           30296
# 2        86.0      150.0           30296
# 3        14.0      133.0           30296
# 2        78.0      150.0           30296
#
# [15755 rows x 18 columns]

# %%
print("Data Successfully Combined")
export_state = False
while not export_state:
    export_path = input("Please input export path directory \n")
    if os.path.exists(export_path) == False:
        print("Please input a correct file path")
    else:
        export_state = True
csv_fname = input("Please input filename")
export_fpath = export_path + "\\" + csv_fname + ".csv"
print(export_fpath)
dcombined.to_csv(path_or_buf = export_fpath, index = False)
# Out:
# Data Successfully Combined
# Please input export path directory
#
# Please input a correct file path
# Please input export path directory
#
# Please input a correct file path
# Please input export path directory
# C:\Users\User\Desktop\New folder (3)
# Please input filenameok
# C:\Users\User\Desktop\New folder (3)\ok.csv

# %%
dcombined.to_csv?
